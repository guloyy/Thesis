# %%
import pandas as pd

df = pd.read_csv('/Users/guloy/Desktop/allah_data.csv')
print(df.columns.tolist())
# Out:
# ['station_id', 'Date', 'site_latitude', 'site_longitude', 'NO3', 'SO4', 'NO3-', 'SO42-']
# /var/folders/kh/9y9vmdj12rj2qxx8l8trt_z80000gn/T/ipykernel_66149/382313298.py:3: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/guloy/Desktop/allah_data.csv')

# %%
import pandas as pd

# Load the CSV file
csv_file_path = '/Users/guloy/Desktop/allah_data.csv'
csv_df = pd.read_csv(csv_file_path)

# Load the Excel file
excel_file_path = '/Users/guloy/Desktop/merged_LU_data_edited.xlsx'
excel_df = pd.read_excel(excel_file_path)

# Perform a left join
joined_df = pd.merge(csv_df, excel_df, how='left', left_on='station_id', right_on='Station_ID')

# Display the first few rows of the joined dataframe for inspection
joined_df.head()

joined_df = joined_df.drop(['Latitude', 'Longitude', 'Station_ID'], axis=1)


joined_df.to_csv('/Users/guloy/Downloads/final_version_camx_withLU.csv', index=False)
# Out:
# /var/folders/kh/9y9vmdj12rj2qxx8l8trt_z80000gn/T/ipykernel_66149/2370969661.py:5: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_df = pd.read_csv(csv_file_path)

# %%
joined_df.head()
# Out:
#   station_id        Date  site_latitude  site_longitude       NO3       SO4  \
# 0      ID404  2013-01-24         45.924           6.687  1.772554  0.268196
# 1      ID404  2013-01-25         45.924           6.687  1.421766  0.771854
# 2      ID404  2013-01-27         45.924           6.687  0.365253  0.166905
# 3      ID404  2013-01-28         45.924           6.687  1.304699  0.396577
# 4      ID404  2013-01-30         45.924           6.687  1.140917  0.744400
#
#        NO3-     SO42-  snow_ice_b1000 ‘1990’  snow_ice_b1000 ‘2000’  ...  \
# 0  7.329766  1.797281                    0.0                    0.0  ...
# 1  8.805204  1.745279                    0.0                    0.0  ...
# 2   3.54718  1.288611                    0.0                    0.0  ...
# 3  1.961125  0.986848                    0.0                    0.0  ...
# 4  0.911713  1.052647                    0.0                    0.0  ...
#
# ...

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('/Users/guloy/Downloads/final_version_camx_withLU.csv')

# Rename the column
df.rename(columns={"urban_fabric_b1000 ‘2018'": "urban_fabric_b1000 ‘2018’"}, inplace=True)
df.rename(columns={"imd_b1000 ‘2018'": "imd_b1000 ‘2018’"}, inplace=True)
df.rename(columns={"imd_b1000 ‘2006'": "imd_b1000 ‘2006’"}, inplace=True)
df.rename(columns={"industrial_transport_b1000 ‘1990'": "industrial_transport_b1000 ‘1990’"}, inplace=True)
df.rename(columns={"population_density ‘2015'": "population_density ‘2015’"}, inplace=True)

# Save the modified DataFrame to a new CSV file
df.to_csv('/Users/guloy/Downloads/final_version_camx_withLU.csv', index=False)
# Out:
# /var/folders/kh/9y9vmdj12rj2qxx8l8trt_z80000gn/T/ipykernel_66149/3319835550.py:4: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/guloy/Downloads/final_version_camx_withLU.csv')

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('/Users/guloy/Downloads/final_version_camx_withLU.csv')

# Convert the 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'])


# Define the year columns with their exact names
year_columns = {
    "snow_ice_b1000 ‘1990’": "1990",
    "snow_ice_b1000 ‘2000’": "2000",
    "snow_ice_b1000 ‘2006’": "2006",
    "snow_ice_b1000 ‘2012’": "2012",
    "snow_ice_b1000 ‘2018’": "2018",

    "urban_fabric_b1000 ‘1990’": "1990",
    "urban_fabric_b1000 ‘2000’": "2000",
    "urban_fabric_b1000 ‘2006’": "2006",
    "urban_fabric_b1000 ‘2012’": "2012",
    "urban_fabric_b1000 ‘2018’": "2018",

    "industrial_transport_b1000 ‘1990’": "1990",
    "industrial_transport_b1000 ‘2000’": "2000",
    "industrial_transport_b1000 ‘2006’": "2006",
    "industrial_transport_b1000 ‘2012’": "2012",
    "industrial_transport_b1000 ‘2018’": "2018",

    "agriculture_b1000 ‘1990’": "1990",
    "agriculture_b1000 ‘2000’": "2000",
    "agriculture_b1000 ‘2006’": "2006",
    "agriculture_b1000 ‘2012’": "2012",
    "agriculture_b1000 ‘2018’": "2018",

    "barren_b1000 ‘1990’": "1990",
    "barren_b1000 ‘2000’": "2000",
    "barren_b1000 ‘2006’": "2006",
    "barren_b1000 ‘2012’": "2012",
    "barren_b1000 ‘2018’": "2018",

    "ports_b500_b1000 ‘1990’": "1990",
    "ports_b500_b1000 ‘2000’": "2000",
    "ports_b500_b1000 ‘2006’": "2006",
    "ports_b500_b1000 ‘2012’": "2012",
    "ports_b500_b1000 ‘2018’": "2018",

    "water_b1000 ‘1990’": "1990",
    "water_b1000 ‘2000’": "2000",
    "water_b1000 ‘2006’": "2006",
    "water_b1000 ‘2012’": "2012",
    "water_b1000 ‘2018’": "2018",

    "natural_green_b1000 ‘1990’": "1990",
    "natural_green_b1000 ‘2000’": "2000",
    "natural_green_b1000 ‘2006’": "2006",
    "natural_green_b1000 ‘2012’": "2012",
    "natural_green_b1000 ‘2018’": "2018",

    "airports_b1000 ‘1990’": "1990",
    "airports_b1000 ‘2000’": "2000",
    "airports_b1000 ‘2006’": "2006",
    "airports_b1000 ‘2012’": "2012",
    "airports_b1000 ‘2018’": "2018",

    "transport_b1000 ‘1990’": "1990",
    "transport_b1000 ‘2000’": "2000",
    "transport_b1000 ‘2006’": "2006",
    "transport_b1000 ‘2012’": "2012",
    "transport_b1000 ‘2018’": "2018",

    "wetlands_b1000 ‘1990’": "1990",
    "wetlands_b1000 ‘2000’": "2000",
    "wetlands_b1000 ‘2006’": "2006",
    "wetlands_b1000 ‘2012’": "2012",
    "wetlands_b1000 ‘2018’": "2018",

    "industrial_b1000 ‘1990’": "1990",
    "industrial_b1000 ‘2000’": "2000",
    "industrial_b1000 ‘2006’": "2006",
    "industrial_b1000 ‘2012’": "2012",
    "industrial_b1000 ‘2018’": "2018",

    "roads_rails_b1000 ‘1990’": "1990",
    "roads_rails_b1000 ‘2000’": "2000",
    "roads_rails_b1000 ‘2006’": "2006",
    "roads_rails_b1000 ‘2012’": "2012",
    "roads_rails_b1000 ‘2018’": "2018",

    "urban_green_b1000 ‘1990’": "1990",
    "urban_green_b1000 ‘2000’": "2000",
    "urban_green_b1000 ‘2006’": "2006",
    "urban_green_b1000 ‘2012’": "2012",
    "urban_green_b1000 ‘2018’": "2018",
    
    "snow_ice_b500 ‘1990’": "1990",
    "snow_ice_b500 ‘2000’": "2000",
    "snow_ice_b500 ‘2006’": "2006",
    "snow_ice_b500 ‘2012’": "2012",
    "snow_ice_b500 ‘2018’": "2018",

    "urban_fabric_b500 ‘1990’": "1990",
    "urban_fabric_b500 ‘2000’": "2000",
    "urban_fabric_b500 ‘2006’": "2006",
    "urban_fabric_b500 ‘2012’": "2012",
    "urban_fabric_b500 ‘2018’": "2018",

    "industrial_transport_b500 ‘1990’": "1990",
    "industrial_transport_b500 ‘2000’": "2000",
    "industrial_transport_b500 ‘2006’": "2006",
    "industrial_transport_b500 ‘2012’": "2012",
    "industrial_transport_b500 ‘2018’": "2018",

    "agriculture_b500 ‘1990’": "1990",
    "agriculture_b500 ‘2000’": "2000",
    "agriculture_b500 ‘2006’": "2006",
    "agriculture_b500 ‘2012’": "2012",
    "agriculture_b500 ‘2018’": "2018",

    "barren_b500 ‘1990’": "1990",
    "barren_b500 ‘2000’": "2000",
    "barren_b500 ‘2006’": "2006",
    "barren_b500 ‘2012’": "2012",
    "barren_b500 ‘2018’": "2018",

    "ports_b500_b500 ‘1990’": "1990",
    "ports_b500_b500 ‘2000’": "2000",
    "ports_b500_b500 ‘2006’": "2006",
    "ports_b500_b500 ‘2012’": "2012",
    "ports_b500_b500 ‘2018’": "2018",

    "water_b500 ‘1990’": "1990",
    "water_b500 ‘2000’": "2000",
    "water_b500 ‘2006’": "2006",
    "water_b500 ‘2012’": "2012",
    "water_b500 ‘2018’": "2018",

    "natural_green_b500 ‘1990’": "1990",
    "natural_green_b500 ‘2000’": "2000",
    "natural_green_b500 ‘2006’": "2006",
    "natural_green_b500 ‘2012’": "2012",
    "natural_green_b500 ‘2018’": "2018",

    "airports_b500 ‘1990’": "1990",
    "airports_b500 ‘2000’": "2000",
    "airports_b500 ‘2006’": "2006",
    "airports_b500 ‘2012’": "2012",
    "airports_b500 ‘2018’": "2018",

    "transport_b500 ‘1990’": "1990",
    "transport_b500 ‘2000’": "2000",
    "transport_b500 ‘2006’": "2006",
    "transport_b500 ‘2012’": "2012",
    "transport_b500 ‘2018’": "2018",

    "wetlands_b500 ‘1990’": "1990",
    "wetlands_b500 ‘2000’": "2000",
    "wetlands_b500 ‘2006’": "2006",
    "wetlands_b500 ‘2012’": "2012",
    "wetlands_b500 ‘2018’": "2018",

    "industrial_b500 ‘1990’": "1990",
    "industrial_b500 ‘2000’": "2000",
    "industrial_b500 ‘2006’": "2006",
    "industrial_b500 ‘2012’": "2012",
    "industrial_b500 ‘2018’": "2018",

    "roads_rails_b500 ‘1990’": "1990",
    "roads_rails_b500 ‘2000’": "2000",
    "roads_rails_b500 ‘2006’": "2006",
    "roads_rails_b500 ‘2012’": "2012",
    "roads_rails_b500 ‘2018’": "2018",

    "urban_green_b500 ‘1990’": "1990",
    "urban_green_b500 ‘2000’": "2000",
    "urban_green_b500 ‘2006’": "2006",
    "urban_green_b500 ‘2012’": "2012",
    "urban_green_b500 ‘2018’": "2018",


   
    "imd_b500 ‘2006’": "2006",
    "imd_b500 ‘2009’": "2009",
    "imd_b500 ‘2012’": "2012",
    "imd_b500 ‘2015’": "2015",
    "imd_b500 ‘2018’": "2018",
    "imd_b1000 ‘2006’": "2006",
    "imd_b1000 ‘2009’": "2009",
    "imd_b1000 ‘2012’": "2012",
    "imd_b1000 ‘2015’": "2015",
    "imd_b1000 ‘2018’": "2018",
    "imd ‘2006’": "2006",
    "imd ‘2009’": "2009",
    "imd ‘2012’": "2012",
    "imd ‘2015’": "2015",
    "imd ‘2018’": "2018",
    "CLC ‘2006’": "2006",
    "CLC ‘2012’": "2012",
    "CLC ‘2018’": "2018",

    "population_density_b501 ‘2000’": "2000",
    "population_density_b501 ‘2020’": "2020",
    "population_density_b1000 ‘2000’": "2000",
    "population_density_b1000 ‘2005’": "2005",
    "population_density_b1000 ‘2010’": "2010",
    "population_density_b1000 ‘2015’": "2015",
    "population_density_b1000 ‘2020’": "2020",
    "population_density_b500 ‘2010’": "2010",
    "population_density_b500 ‘2015’": "2015",
    "population_density_b500 ‘2020’": "2020",
    "population_density ‘2005’": "2005",
    "population_density ‘2010’": "2010",
    "population_density ‘2015’": "2015",
    "population_density ‘2020’": "2020"
    
}



# Function to find the closest year
def closest_year(date, year_columns):
    year = date.year
    closest_col_name = min(year_columns.keys(), key=lambda col_name: abs(int(year_columns[col_name]) - year))
    return closest_col_name

# Apply the function and create the new column
df['imd_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['imd_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['imd'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['CLC'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['snow_ice_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['snow_ice_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['urban_fabric_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['urban_fabric_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['industrial_transport_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['industrial_transport_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['agriculture_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['agriculture_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['barren_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['barren_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['water_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['water_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['ports_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['ports_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['transport_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['transport_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['natural_green_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['natural_green_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['airports_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['airports_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['wetlands_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['wetlands_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['industrial_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['industrial_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
#df['airports_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
#df['airports_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['roads_rails_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['roads_rails_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['urban_green_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['urban_green_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['population_density_b1000'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['population_density_b500'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['population_density_b501'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)
df['population_density'] = df.apply(lambda row: row[closest_year(row['Date'], year_columns)], axis=1)


# Save the modified DataFrame back to a new CSV file
df.to_csv('/Users/guloy/Downloads/final_version_camx_withLU.csv', index=False)
# Out:
# /var/folders/kh/9y9vmdj12rj2qxx8l8trt_z80000gn/T/ipykernel_66149/2791875343.py:4: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/guloy/Downloads/final_version_camx_withLU.csv')

# %%
import pandas as pd

# Load the CSV file into a DataFrame
file_path = '/Users/guloy/Downloads/final_version_camx_withLU.csv'  # Replace with your actual file path
df = pd.read_csv(file_path)

# Print the column names
print(df.columns)
# Out:
# /var/folders/kh/9y9vmdj12rj2qxx8l8trt_z80000gn/T/ipykernel_66149/1724329383.py:5: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Index(['station_id', 'Date', 'site_latitude', 'site_longitude', 'NO3', 'SO4',
#        'NO3-', 'SO42-', 'snow_ice_b1000 ‘1990’', 'snow_ice_b1000 ‘2000’',
#        ...
#        'industrial_b1000', 'industrial_b500', 'roads_rails_b1000',
#        'roads_rails_b500', 'urban_green_b1000', 'urban_green_b500',
#        'population_density_b1000', 'population_density_b500',
#        'population_density_b501', 'population_density'],
#       dtype='object', length=252)

# %%
import pandas as pd

# Load the CSV file
file_path = '/Users/guloy/Downloads/final_version_camx_withLU.csv'
df = pd.read_csv(file_path)

# Identify the column indices for 'snow_ice_b1000 ‘1990’' and 'CLC ‘2006’'
# Note: Replace 'CLC ‘2006’' with the actual name of the end column if it's different
start_column = 'snow_ice_b1000 ‘1990’'
end_column = 'CLC ‘2006’'

# Ensure both columns exist in the DataFrame
if start_column in df.columns and end_column in df.columns:
    start_idx = df.columns.get_loc(start_column)
    end_idx = df.columns.get_loc(end_column)

    # Delete all columns between these indices, inclusive
    df.drop(df.columns[start_idx:end_idx + 1], axis=1, inplace=True)
else:
    print(f"Could not find columns '{start_column}' and/or '{end_column}' in the DataFrame.")

# Save the modified DataFrame to a new CSV file
new_file_path = '/Users/guloy/Downloads/final_version_camx_withLU.csv'
df.to_csv(new_file_path, index=False)
# Out:
# /var/folders/kh/9y9vmdj12rj2qxx8l8trt_z80000gn/T/ipykernel_66149/2050219529.py:5: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
import pandas as pd

# Load the CSV file into a DataFrame
file_path = '/Users/guloy/Downloads/final_version_camx_withLU.csv'  # Replace with your actual file path
df = pd.read_csv(file_path)

# Print the column names
print(df.columns)
print(df.shape)
# Out:
# Index(['station_id', 'Date', 'site_latitude', 'site_longitude', 'NO3', 'SO4',
#        'NO3-', 'SO42-', 'elevation_1k', 'elevation_yNA_bNA',
#        'road_class_1_700', 'road_class_2_50', 'road_class_1_500',
#        'road_class_3_50', 'road_class_2_400', 'road_class_1_100',
#        'road_class_2_700', 'road_class_3_100', 'road_class_2_500',
#        'road_class_1_400', 'road_class_3_400', 'road_class_1_2000',
#        'road_class_3_1000', 'road_class_3_10000', 'road_class_1_300',
#        'road_class_3_500', 'road_class_2_2000', 'road_class_1_1000',
#        'road_class_3_300', 'road_class_2_200', 'road_class_1_200',
#        'road_class_2_1000', 'road_class_1_5000', 'road_class_1_50',
#        'road_class_3_200', 'road_class_3_5000', 'road_class_2_300',
#        'road_class_2_5000', 'road_class_3_2000', 'road_class_2_100',
#        'road_class_3_700', 'road_class_2_10000', 'road_class_1_10000',
#        'imd_b500', 'imd_b1000', 'imd', 'CLC', 'snow_ice_b1000',
# ...
